# %% [markdown]
# # Виды распределений

# %% [markdown]
# Загрузить таблицу и построить график распределений. Найти нормальное распределение.

# %%
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import io
import requests
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# Таблица цен на дома в Бостоне

# %% [markdown]
# Основные значения:
#
# * CRIM: This is the per capita crime rate by town
# * ZN: This is the proportion of residential land zoned for lots larger than 25,000 sq.ft.
# * INDUS: This is the proportion of non-retail business acres per town.
# * CHAS: This is the Charles River dummy variable (this is equal to 1 if tract bounds river; 0 otherwise)
# * NOX: This is the nitric oxides concentration (parts per 10 million)
# * RM: This is the average number of rooms per dwelling
# * AGE: This is the proportion of owner-occupied units built prior to 1940
# * DIS: This is the weighted distances to five Boston employment centers
# * RAD: This is the index of accessibility to radial highways
# * TAX: This is the full-value property-tax rate per 10,000 dollars
# * PTRATIO: This is the pupil-teacher ratio by town
# * B: This is calculated as 1000(Bk — 0.63)², where Bk is the proportion of people of African American descent by town
# * LSTAT: This is the percentage lower status of the population
# * MEDV: This is the median value of owner-occupied homes in 1000 dollars

# %%
url='http://yustiks.ru/housing.csv'
s=requests.get(url).content
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data=pd.read_csv(io.StringIO(s.decode('utf-8')),  delim_whitespace=True, names=names)
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31     0  0.538  ...  296.0     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242.0     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242.0     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222.0     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222.0     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %% [markdown]
# Нарисовать частотные графики для всех значений. Можете ли вы найти следующие распределения в данных графиках?
#
#
# 1.   Нормальное
# 2.   Равномерное
# 3.   Биноминальное
# 4.   Бернулли
# 5.   Геометрическое
# 6.   Логнормальное

# %%
CRIM = data['CRIM']
sns.distplot(CRIM)
plt.title('Плотность вероятности распределения CRIM')
plt.show()

# %%
ZN = data['ZN']
sns.distplot(ZN)
plt.title('Плотность вероятности распределения ZN')
plt.show()

# %%
INDUS = data['INDUS']
sns.distplot(INDUS)
plt.title('Плотность вероятности распределения INDUS')
plt.show()

# %%
CHAS = data['CHAS']
sns.distplot(CHAS)
plt.title('Плотность вероятности распределения CHAS')
plt.show()

# %%
NOX = data['NOX']
sns.distplot(NOX)
plt.title('Плотность вероятности распределения NOX')
plt.show()

# %%
RM = data['RM']
sns.distplot(RM)
plt.title('Плотность вероятности распределения RM')
plt.show()

# %%
AGE = data['AGE']
sns.distplot(AGE)
plt.title('Плотность вероятности распределения AGE')
plt.show()

# %%
DIS = data['DIS']
sns.distplot(DIS)
plt.title('Плотность вероятности распределения DIS')
plt.show()

# %%
RAD = data['RAD']
sns.distplot(RAD)
plt.title('Плотность вероятности распределения RAD')
plt.show()

# %%
TAX = data['TAX']
sns.distplot(TAX)
plt.title('Плотность вероятности распределения TAX')
plt.show()

# %%
PTRATIO = data['PTRATIO']
sns.distplot(PTRATIO)
plt.title('Плотность вероятности распределения PTRATIO')
plt.show()

# %%
B = data['B']
sns.distplot(B)
plt.title('Плотность вероятности распределения B')
plt.show()

# %%
LSTAT = data['LSTAT']
sns.distplot(LSTAT)
plt.title('Плотность вероятности распределения LSTAT')
plt.show()

# %%
MEDV = data['MEDV']
sns.distplot(MEDV)
plt.title('Плотность вероятности распределения MEDV')
plt.show()

# %% [markdown]
# Среди графиков встречаются такие типы распределений как нормальное (RM), биноминальное (LSTAT) и логнормальное(CRIM), Бернулли (CHAS)

# %%
# Напишите код, который будет рисовать распределения попарно - точечные распределение
url="http://yustiks.ru/dataset/world-happiness-report-2019.csv"
df=pd.read_csv(url)

# %%
sns.set(style="ticks", color_codes=True)
g = sns.pairplot(data)

# %% [markdown]
# Загрузить таблицу Happiness report. Нарисовать матрицу ковариаций попарно.

# %%
url="http://yustiks.ru/dataset/world-happiness-report-2019.csv"
data=pd.read_csv(url)
data.head()
# Out:
#   Country (region)  Ladder  ...  Log of GDP\nper capita  Healthy life\nexpectancy
# 0          Finland       1  ...                    22.0                      27.0
# 1          Denmark       2  ...                    14.0                      23.0
# 2           Norway       3  ...                     7.0                      12.0
# 3          Iceland       4  ...                    15.0                      13.0
# 4      Netherlands       5  ...                    12.0                      18.0
#
# [5 rows x 11 columns]

# %%
data= data.dropna(subset=['Country (region)'])
data= data.dropna(subset=['Ladder'])
data= data.dropna(subset=['SD of Ladder'])
data= data.dropna(subset=['Positive affect'])
data= data.dropna(subset=['Negative affect'])
data= data.dropna(subset=['Social support'])
data= data.dropna(subset=['Freedom'])
data= data.dropna(subset=['Corruption'])
data= data.dropna(subset=['Generosity'])

# %%
X = data.iloc[:,1:8]
X.head()
# Out:
#    Ladder  SD of Ladder  Positive affect  ...  Social support  Freedom  Corruption
# 0       1             4             41.0  ...             2.0      5.0         4.0
# 1       2            13             24.0  ...             4.0      6.0         3.0
# 2       3             8             16.0  ...             3.0      3.0         8.0
# 3       4             9              3.0  ...             1.0      7.0        45.0
# 4       5             1             12.0  ...            15.0     19.0        12.0
#
# [5 rows x 7 columns]

# %% [markdown]
# P.S. Пришлось удалить "Log of GDP per capita" и "Healthy life expectancy",  выходила ошибка при попытке удалить выбросные значения, матрица считалась из за этого неправильно

# %%
np.cov(X)
# Out:
# array([[ 200.28571429,  100.23809524,   60.66666667, ...,  127.54761905,
#          -37.92857143,  -37.5       ],
#        [ 100.23809524,  102.80952381,   87.        , ...,  -69.07142857,
#           -2.35714286,   63.16666667],
#        [  60.66666667,   87.        ,   92.        , ...,  -17.16666667,
#           20.        ,    7.        ],
#        ...,
#        [ 127.54761905,  -69.07142857,  -17.16666667, ..., 2198.95238095,
#          443.76190476,   25.66666667],
#        [ -37.92857143,   -2.35714286,   20.        , ...,  443.76190476,
#          260.14285714,  311.        ],
#        [ -37.5       ,   63.16666667,    7.        , ...,   25.66666667,
#          311.        , 1136.33333333]])

# %%
print(np.shape(np.cov(X)))
# Out:
# (148, 148)

# %%
np.cov(X.T)
# Out:
# array([[2071.83429858, 1165.51737452, 1007.38821475, 1110.24094503,
#         1720.35484464, 1108.57607097,  370.87414966],
#        [1165.51737452, 2090.19709505,  197.26677698, 1290.07850708,
#         1241.98584299,  533.92369921,  506.89795918],
#        [1007.38821475,  197.26677698, 2033.50523993,  788.12024269,
#          842.69148741, 1384.57299136,  405.29251701],
#        [1110.24094503, 1290.07850708,  788.12024269, 2060.80400809,
#         1317.67089539,  879.17567568,  309.23129252],
#        [1720.35484464, 1241.98584299,  842.69148741, 1317.67089539,
#         2065.52895753,  945.17926089,  230.7414966 ],
#        [1108.57607097,  533.92369921, 1384.57299136,  879.17567568,
#          945.17926089, 2028.91170252,  736.26870748],
#        [ 370.87414966,  506.89795918,  405.29251701,  309.23129252,
#          230.7414966 ,  736.26870748, 1837.66666667]])

# %%
standardized = (X - X.mean()) / X.std()
np.cov(standardized.T)
# Out:
# array([[1.        , 0.56007685, 0.49079113, 0.53730562, 0.83161992,
#         0.54070006, 0.19007092],
#        [0.56007685, 1.        , 0.09568364, 0.62159022, 0.5977332 ,
#         0.25927104, 0.25863873],
#        [0.49079113, 0.09568364, 1.        , 0.38499181, 0.41117842,
#         0.68165031, 0.20965855],
#        [0.53730562, 0.62159022, 0.38499181, 1.        , 0.63866478,
#         0.42995771, 0.15890286],
#        [0.83161992, 0.5977332 , 0.41117842, 0.63866478, 1.        ,
#         0.46170754, 0.11843408],
#        [0.54070006, 0.25927104, 0.68165031, 0.42995771, 0.46170754,
#         1.        , 0.38130403],
#        [0.19007092, 0.25863873, 0.20965855, 0.15890286, 0.11843408,
#         0.38130403, 1.        ]])

# %% [markdown]
# Сколько в данной таблице отсутствующих значений? Написать ответ. Если есть отсутствующие значения в выборке country, убрать (drop). Написать код.

# %% [markdown]
# Отсутствующих значений нет, так как все выбросы были удалены

# %% [markdown]
# Сколько стран в выборке? Написать ответ. Можно ли сказать, что данные значения - это **проблема классификации**?

# %%
data['Country (region)'].nunique()
# Out:
# 148

# %% [markdown]
# Нарисовать sns.pairplot для класс - страна. Из графика сделать вывод о том, какие страны похожи.

# %%
Y = data.iloc[:20,:8]
Y
# Out:
#    Country (region)  Ladder  SD of Ladder  ...  Social support  Freedom  Corruption
# 0           Finland       1             4  ...             2.0      5.0         4.0
# 1           Denmark       2            13  ...             4.0      6.0         3.0
# 2            Norway       3             8  ...             3.0      3.0         8.0
# 3           Iceland       4             9  ...             1.0      7.0        45.0
# 4       Netherlands       5             1  ...            15.0     19.0        12.0
# 5       Switzerland       6            11  ...            13.0     11.0         7.0
# 6            Sweden       7            18  ...            25.0     10.0         6.0
# 7       New Zealand       8            15  ...             5.0      8.0         5.0
# 8            Canada       9            23  ...            20.0      9.0        11.0
# 9           Austria      10            10  ...            31.0     26.0        19.0
# ...

# %%
# Если код ниже не работает, измените код, используя материал лекций. Пишите на почту, если испытываете проблемы: yustiks@gmail.com
sns.set(style="ticks", color_codes=True)
fig = sns.pairplot(data=Y, hue='Country (region)')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# По заданным параметрам наибольшую схожесть имеют Финляндия, Дания и Норвегия

# %% [markdown]
# Посчитать матрицу корреляций для таблицы. Написать код. Сделать график. Какие можно сделать выводы?

# %%
X.corr()
# Out:
#                    Ladder  SD of Ladder  ...   Freedom  Corruption
# Ladder           1.000000      0.560077  ...  0.540700    0.190071
# SD of Ladder     0.560077      1.000000  ...  0.259271    0.258639
# Positive affect  0.490791      0.095684  ...  0.681650    0.209659
# Negative affect  0.537306      0.621590  ...  0.429958    0.158903
# Social support   0.831620      0.597733  ...  0.461708    0.118434
# Freedom          0.540700      0.259271  ...  1.000000    0.381304
# Corruption       0.190071      0.258639  ...  0.381304    1.000000
#
# [7 rows x 7 columns]

# %%
import seaborn as sns
sns.heatmap(X.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->correlation matrix
fig=plt.gcf()
fig.set_size_inches(12,12)
plt.show()

# %% [markdown]
# Наибольшую корреляцию имеют "Social support" и "Ladder"

# %% [markdown]
# **Регрессионный анализ** - можно ли провести линейную зависимость между двумя выборками. Возьмем Ladder - удовлетворение жизнью, и generosity - доброта. Мы хотим найти прямую, которая разделит точки в пространстве наполовину. Это можно сделать графически. Нарисовать график. Можно ли сказать, что данная прямая является собственным вектором? При проецировании данных на эту прямую разброс данных максимален?

# %% [markdown]
# # Дискретное распределение случайной величины

# %% [markdown]
# Напишите код для моделирования 10 подбрасываний игрального кубика. Начертите диаграму histogram. Какое это распределение?

# %%
import pylab
import numpy

# Количество испытаний
trials = 10
# Массив значений
values = numpy.random.randint(1, 7, size=trials)
pylab.hist(values, bins=[0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5], edgecolor='white')

pylab.xlabel('Значение')
pylab.ylabel('Количества раз')
pylab.title('Подбрасывание кубика ' + str(trials) + ' раз')
pylab.show()

# %% [markdown]
# Напишите код для моделирования 1000 подбрасываний игрального кубика. Начертите диаграму histogram. Почему график изменился? Как применить центральную предельную теорему?

# %%
import pylab
import numpy

# Количество испытаний
trials = 1000
# Массив значений
values = numpy.random.randint(1, 7, size=trials)
pylab.hist(values, bins=[0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5], edgecolor='white')

pylab.xlabel('Значение')
pylab.ylabel('Количества раз')
pylab.title('Подбрасывание кубика ' + str(trials) + ' раз')
pylab.show()

# %% [markdown]
# С увеличением количества испытаний увеличивается вероятность выпадения конкретной стороны кубика
