# %%
#Задание 1
#Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. 
#Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
import pandas as pd
data = pd.read_csv(r'C:\Users\af.sabirova\Desktop\pyda\HW_6\ratings.csv')
data.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %%
data_movie = data[ (data['rating']==5) ]
data_movie['movieId'].value_counts().head(1)
# Out:
# 318    1659
# Name: movieId, dtype: int64

# %%
#Задание 2
#По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
import pandas as pd
power = pd.read_csv(r'C:\Users\af.sabirova\Desktop\pyda\6_lek\power.csv')
power_baltic = power [ ((power['country']== 'Estonia') | (power['country']== 'Lithuania') | (power['country']== 'Latvia')) \
                     & ((power['category']== 4) | (power['category']== 12) | (power['category']== 21))  & \
                    power['year'].between(2005,2010, inclusive=True) ]
power_baltic.head()
# Out:
#          country  year  quantity  category
# 10617    Estonia  2008       1.0         4
# 10618    Estonia  2007       0.0         4
# 10619    Estonia  2006       0.0         4
# 10620    Estonia  2005       1.0         4
# 11156  Lithuania  2008       1.0         4

# %%
#Задание 3
#Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
#Примеры страниц (необязательно брать именно эти):
#https://fortrader.org/quotes
#https://www.finanz.ru/valyuty/v-realnom-vremeni

# %%
import pandas as pd
pd.read_html('https://fortrader.org/quotes')
# Out:
# [                               Type    Last   Chg.  Chg.%  Time
#  0  Нефть (BRENT) Курс нефти сегодня  60.430  0.830  1.390   NaN
#  1   Нефть (WTI) Цены на нефть (WTI)  56.660  0.590  1.050   NaN
#  2          Сахар котировки на сахар  12.630  0.000  0.000   NaN
#  3                   Газ Цена на газ   2.225  0.016  0.724   NaN,
#                                      Type          Last      Chg.     Chg.%  \
#  0                      ВТБ Акции ОАО ВТБ       0.03922  -0.00017  -0.43158
#  1                 Газпром Акции газпрома     230.91000     -0.97  -0.42000
#  2                    Лукоил Акции Лукойл    5276.00000     -43.0  -0.80000
#  3                Роснефть Акции Роснефти     411.60000     +3.55   0.87000
#  4               Сбербанк Акции Сбербанка     216.87000     +0.82   0.38000
#  5   Сургутнефтегаз Акции Сургутнефтегаза      25.85500    -0.235  -0.90100
#  6              Норникель Акции Норникель   15082.00000       -76  -1.00000
# ...
